# %%
import pandas as pd
import folium
from folium.plugins import HeatMap

# %%
gut_place_data = pd.read_csv('data/final/gut_place.csv', sep=';')

# %%
gut_place_data
# Out:
#       Latitude  Longitude     Distance
# 0    56.007634  37.797262  5141.766473
# 1    55.992985  37.168481  5592.220499
# 2    55.616954  37.315334  3203.782659
# 3    55.789978  37.799032  3698.631756
# 4    55.816885  37.823017  3018.826508
# ..         ...        ...          ...
# 663  55.966030  37.187755  4416.818112
# 664  55.793207  37.814429  3896.539756
# 665  55.970878  37.150795  6536.635919
# 666  55.692130  37.744720  3486.095855
# 667  55.901521  37.571107  3282.592211
#
# [668 rows x 3 columns]

# %%
map = folium.Map(location=[55.751244, 37.618423], zoom_start=10, zoom_min=7)

# %%
for location in gut_place_data.values:
    folium.Marker([location[0], location[1]]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.save('gut_place.3k.html')

# %%
heatmap = folium.Map(location=[55.751244, 37.618423], zoom_start=10, zoom_min=7)

# %%
gradient = {.01:'braun', .5:'green', 1:'lime'} # gradient=gradient
HeatMap([[p[0], p[1]] for p in gut_place_data.values], 
        #max_value=1000,
        #radius=10, 
        #gradient=gradient
       ).add_to(heatmap)

# %%
heatmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
heatmap.save('gut_place_heatmap.html')

# %%
heatmap.
